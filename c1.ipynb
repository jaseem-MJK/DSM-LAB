# %%
n1=int(input("Enter first number: "))
n2=int(input("Enter second number: "))
choice=int(input("Enter a choice:1 addition 2.substraction 3.multiplication 4.division "))
if choice==1:
    addition=n1+n2;
    print(addition)
elif choice==2:
    substraction=n1-n2;
    print(substraction)
elif choice==3:
    multiplication=n1*n2;
    print(multiplication)
elif choice==4:
    division =n1/n2
    print(division)
else:
    print("error")
# Out:
# Enter first number: 2
# Enter second number: 4
# Enter a choice:1 addition 2.substraction 3.multiplication 4.division 1
# 6

# %%
n1=int(input("Enter first number: "))
n2=int(input("Enter second number: "))
print(n1>n2)
print(n1<n2)
print(n1>=n2)
print(n1<=n2)
print(n1 and n2)
print(n1 or n2)
# Out:
# Enter first number: 2
# Enter second number: 5
# False
# True
# False
# True
# 5
# 2

# %%
dict1 = {"name":"jsm", "age": 22}
dict2 = {"place":"edp", "weight": 65}
dict1.update(dict2)
print(dict1)
# Out:
# {'name': 'jsm', 'age': 22, 'place': 'edp', 'weight': 65}

# %%
a=int(input("Enter first value"))
b=int(input("Enter second value"))
c=int(input("Enter third value"))
if a > b and a>c:
    print(a) 
elif  b>c:
    print(b)
else:
    print(c)
# Out:
# Enter first value50
# Enter second value60
# Enter third value40
# 60
